# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 21 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=4d114218d716fcbbb14aaced295a61062c9d2a1c51add46b868cb1da72b2a89e
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
import face_recognition

image = face_recognition.load_image_file("/content/download.jpg")
face_locations = face_recognition.face_locations(image)

# face_locations is now an array listing the co-ordinates of each face!

# %%
from IPython.display import Image
Image('/content/pic1.jpg', width=500, height=500)

# %%
from IPython.display import Image
Image('/content/download.jpg', width=500, height=500)

# %%
import face_recognition

picture_of_me = face_recognition.load_image_file("/content/pic1.jpg")
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]

# my_face_encoding now contains a universal 'encoding' of my facial features that can be compared to any other picture of a face!

unknown_picture = face_recognition.load_image_file("/content/download.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# Now we can see the two face encodings are of the same person with `compare_faces`!

results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)

if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's not a picture of me!
